# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/insurance-company-complaints/Insurance_Company_Complaints__Resolutions__Status__and_Recoveries.csv

# %%
data = pd.read_csv('/kaggle/input/insurance-company-complaints/Insurance_Company_Complaints__Resolutions__Status__and_Recoveries.csv')
data
# Out:
#                                                  Company  File No.  \
# 0                               Anthem Health Plans, Inc   7045593
# 1                               Anthem Health Plans, Inc   7043381
# 2                               Anthem Health Plans, Inc   7044860
# 3                               Anthem Health Plans, Inc   7043381
# 4                               Anthem Health Plans, Inc   7052007
# ...                                                  ...       ...
# 38262                        New South Insurance Company   7006954
# 38263                      Liberty Insurance Corporation   7010204
# 38264  Farmers Group Property and Casualty Insurance ...   7015842
# 38265                            Casco Indemnity Company   7005412
# 38266                           Anthem Health Plans, Inc   7043907
#
#            Opened      Closed                               Coverage  \
# 0      05/31/2022  06/02/2022                                  Group
# ...

# %%
from sklearn.model_selection import train_test_split

y = data.Recovery
X = data.drop(['Company','Recovery'], axis = 1)

X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size = 0.8, test_size = 0.2)

# %%
object_cols2 = [col for col in X.columns
               if X[col].dtype == 'object']
object_cols=object_cols2[4:]
print(object_cols)

num_cols = [col for col in X.columns
           if X[col].dtype in ['int64', 'float64']]
# Out:
# ['Coverage', 'SubCoverage']

# %%
def score_dataset(X_train, X_valid, y_train, y_valid):
    model = RandomForestRegressor(n_estimators=100, random_state=0)
    model.fit(X_train, y_train)
    preds = model.predict(X_valid)
    return mean_absolute_error(y_valid, preds)

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.ensemble import RandomForestRegressor

my_encoder = OrdinalEncoder()

encod_X_train = X_train.copy()
encod_X_valid = X_valid.copy()

encod_X_train[object_cols] = my_encoder.fit_transform(X_train[object_cols])
encod_X_valid[object_cols] = my_encoder.transform(X_valid[object_cols])

score_dataset(X_train, X_valid, y_train, y_valid)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[92], line 10
#       7 encod_X_valid = X_valid.copy()
#       9 encod_X_train[object_cols] = my_encoder.fit_transform(X_train[object_cols])
# ---> 10 encod_X_valid[object_cols] = my_encoder.transform(X_valid[object_cols])
#      12 score_dataset(X_train, X_valid, y_train, y_valid)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
# ...
